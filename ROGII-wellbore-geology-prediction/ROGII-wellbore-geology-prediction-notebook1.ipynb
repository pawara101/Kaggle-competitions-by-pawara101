# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os

# %%
type_well = pd.read_csv("/kaggle/input/competitions/rogii-wellbore-geology-prediction/train/05a0ee4d__typewell.csv")

# %%
horizontal_well = pd.read_csv("/kaggle/input/competitions/rogii-wellbore-geology-prediction/train/05a0ee4d__horizontal_well.csv")

# %%
from IPython.display import Image, display

display(Image(filename="/kaggle/input/competitions/rogii-wellbore-geology-prediction/train/05a0ee4d.png"))

# %%
type_well
# Out:
#            TVT      GR Geology
# 0     11223.95  126.11     NaN
# 1     11224.45  128.22     NaN
# 2     11224.95  128.72     NaN
# 3     11225.45  128.12     NaN
# 4     11225.95  125.29     NaN
# ...        ...     ...     ...
# 1291  11869.45   38.72    BUDA
# 1292  11869.95   39.16    BUDA
# 1293  11870.45   39.46    BUDA
# 1294  11870.95   39.73    BUDA
# 1295  11871.45   39.86    BUDA
#
# [1296 rows x 3 columns]

# %%
horizontal_well
# Out:
#            MD           X           Y        Z     ANCC    ASTNU    ASTNL  \
# 0     10970.0  2994585.45  1100502.46 -8728.84 -9036.41 -9174.96 -9249.90
# 1     10971.0  2994585.44  1100502.46 -8729.84 -9036.40 -9174.96 -9249.90
# 2     10972.0  2994585.43  1100502.47 -8730.84 -9036.40 -9174.96 -9249.90
# 3     10973.0  2994585.42  1100502.47 -8731.84 -9036.40 -9174.96 -9249.90
# 4     10974.0  2994585.42  1100502.47 -8732.84 -9036.40 -9174.95 -9249.89
# ...       ...         ...         ...      ...      ...      ...      ...
# 6093  17063.0  2992518.57  1105679.66 -9262.16 -8816.72 -8955.27 -9030.21
# 6094  17064.0  2992518.18  1105680.58 -9262.10 -8816.70 -8955.26 -9030.20
# 6095  17065.0  2992517.79  1105681.50 -9262.04 -8816.69 -8955.25 -9030.19
# 6096  17066.0  2992517.40  1105682.42 -9261.98 -8816.68 -8955.23 -9030.17
# 6097  17067.0  2992517.01  1105683.34 -9261.93 -8816.66 -8955.22 -9030.16
#
#         EGFDU    EGFDL     BUDA       TVT          GR  TVT_input
# ...
